# %% [markdown]
# ## XGBoost v4
# -

# %%
from dotenv import load_dotenv
import kagglehub
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import StratifiedKFold
from sklearn.utils.class_weight import compute_sample_weight
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, balanced_accuracy_score, classification_report
import torch
from xgboost import XGBClassifier
from scipy.optimize import differential_evolution
import optuna

if torch.cuda.is_available():
    device="cuda"
else:
    device="cpu"
device
# Out:
# 'cuda'

# %%
load_dotenv()

ROOT = Path.cwd()
while not (ROOT / ".git").exists():
    ROOT = ROOT.parent

DATA_DIR = ROOT / "Data"

if not (DATA_DIR / ".complete/competitions/playground-series-s6e6/bundle.complete").is_file():
    kagglehub.competition_download("playground-series-s6e6", output_dir=DATA_DIR)
    print("Data downloaded")
else:
    print("Data not downloaded, already exists")
# Out:
# Data not downloaded, already exists

# %%
train = pd.read_csv(DATA_DIR / "train.csv", index_col="id")
train.head()
# Out:
#          alpha      delta          u          g          r          i  \
# id
# 0   147.734256  16.959273  25.472123  21.895559  20.357926  19.257113
# 1   127.988677  32.346716  20.778509  19.087062  17.587208  17.226067
# 2   179.792648  35.344843  21.035203  21.079128  21.171840  20.582629
# 3   225.818295  48.569421  23.305056  21.050736  19.017754  18.365658
# 4   141.836135  19.342852  21.703158  19.471680  18.234449  17.899447
#
#             z  redshift spectral_type galaxy_population   class
# id
# 0   18.621057  0.408982             M      Red_Sequence  GALAXY
# 1   16.786433  0.157976             M      Red_Sequence  GALAXY
# 2   20.557366  2.823770           O/B        Blue_Cloud     QSO
# 3   17.914952  0.536099             M      Red_Sequence  GALAXY
# 4   17.616185  0.555761             M      Red_Sequence  GALAXY

# %%
def add_features(df):
    df = df.copy()

    bands = ['u', 'g', 'r', 'i', 'z']

    # mag stats
    df['mag_mean'] = df[bands].mean(axis=1)
    df['mag_std'] = df[bands].std(axis=1)
    df['mag_max'] = df[bands].max(axis=1)
    df['mag_min'] = df[bands].min(axis=1)
    df['mag_range'] = df['mag_max'] - df['mag_min']

    # color indices
    df['u_g'] = df['u'] - df['g']
    df['g_r'] = df['g'] - df['r']
    df['r_i'] = df['r'] - df['i']
    df['i_z'] = df['i'] - df['z']
    df['u_r'] = df['u'] - df['r']
    df['u_i'] = df['u'] - df['i']
    df['u_z'] = df['u'] - df['z']
    df['g_i'] = df['g'] - df['i']
    df['g_z'] = df['g'] - df['z']
    df['r_z'] = df['r'] - df['z']

    # spatial trigonometry
    alpha_rad = np.radians(df["alpha"])
    delta_rad = np.radians(df["delta"])
    df["alpha_sin"] = np.sin(alpha_rad)
    df["alpha_cos"] = np.cos(alpha_rad)
    df["delta_sin"] = np.sin(delta_rad)
    df["delta_cos"] = np.cos(delta_rad)

    # redshift interactions
    epsilon = 1e-5
    abs_redshift = df['redshift'].abs() + epsilon
    for col in ['u_g', 'g_r', 'r_i', 'i_z']:
        df[f'{col}_per_redshift'] = df[col] / abs_redshift
    for b in bands:
        df[f'redshift_{b}'] = df['redshift'] * df[b]
    
    return df

# %%
X = add_features(train).drop(columns=["class"])
categorical_cols = ["spectral_type", "galaxy_population"]
for col in categorical_cols:
    X[col] = X[col].astype("category")

le = LabelEncoder()
y = le.fit_transform(train["class"])

test = pd.read_csv(DATA_DIR / "test.csv", index_col="id")
test = add_features(test)
for col in categorical_cols:
    test[col] = test[col].astype("category")

# %%
storage = f"sqlite:///{ROOT / 'Models/XGBoost/optuna_xgboost.db'}"
study_name = "2"

study = optuna.load_study(
    study_name=study_name,
    storage=storage,
)

print("Best value:", study.best_value)
print("Best params:", study.best_params)
print("Best trial:", study.best_trial.number)
# Out:
# Best value: 0.9659221915135623
# Best params: {'learning_rate': 0.007116315160205815, 'max_depth': 8, 'min_child_weight': 5, 'max_delta_step': 1, 'gamma': 0.5977522252907134, 'reg_alpha': 1.5533717490656684, 'reg_lambda': 2.437160235192563, 'subsample': 0.8910948501868639, 'colsample_bytree': 0.7759866091917986, 'colsample_bylevel': 0.9840731813445621}
# Best trial: 52

# %%
import optuna
from pathlib import Path

ROOT = Path.cwd()
while not (ROOT / ".git").exists():
    ROOT = ROOT.parent

storage = f"sqlite:///{ROOT / 'Models/XGBoost/optuna_xgboost.db'}"
study_name = "n_est_cap_3"  # change this

study = optuna.load_study(study_name=study_name, storage=storage)

df = study.trials_dataframe(attrs=("number", "value", "params", "user_attrs", "state"))

cols = [
    "number",
    "value",
    "params_learning_rate",
    "params_max_depth",
    "params_min_child_weight",
    "params_gamma",
    "params_reg_alpha",
    "params_reg_lambda",
    "params_subsample",
    "params_colsample_bytree",
    "params_colsample_bylevel",
    "user_attrs_mean_best_iteration",
    "user_attrs_max_best_iteration",
    "user_attrs_mean_rounds_trained",
    "user_attrs_max_rounds_trained",
    "user_attrs_hit_n_estimators_cap",
    "state",
]

existing_cols = [c for c in cols if c in df.columns]

df[existing_cols].sort_values("value", ascending=False)
# Out:
#    number value  params_learning_rate  params_max_depth  \
# 0       0  None              0.014667                 6
#
#    params_min_child_weight  params_gamma  params_reg_alpha  params_reg_lambda  \
# 0                       11      0.149065          1.719808           1.608976
#
#    params_subsample  params_colsample_bytree  params_colsample_bylevel state
# 0           0.68948                 0.638868                  0.602202  FAIL

# %%
n_splits = 5
SEEDS = [42, 2024, 777]

test_probs = np.zeros((len(test), 3))
oof_probs = np.zeros((len(X), 3))

fold_histories = []

for seed in SEEDS:
    print(f'Using seed {seed}')

    skf = StratifiedKFold(
        n_splits=n_splits,
        shuffle=True,
        random_state=seed
    )

    for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
        X_train = X.iloc[train_idx]
        X_val = X.iloc[val_idx]

        y_train = y[train_idx]
        y_val = y[val_idx]
        
        sample_weights = compute_sample_weight(
            class_weight="balanced",
            y=y_train
        )

        model = XGBClassifier(
            **study.best_params,
            device=device,
            random_state=seed,
            n_estimators=6000,
            early_stopping_rounds=150,
            enable_categorical=True,
            verbosity=0
        )

        print(f'Training fold {fold}')

        model.fit(
            X_train,
            y_train,
            sample_weight=sample_weights,
            eval_set=[(X_val, y_val)],
            verbose=False
        )

        fold_histories.append(model.evals_result())

        oof_probs[val_idx] += model.predict_proba(X_val) / len(SEEDS)
        test_probs += model.predict_proba(test) / (n_splits * len(SEEDS))

oof_preds = np.argmax(oof_probs, axis=1)
# Out:
# Using seed 42
# Training fold 1
# Training fold 2
# Training fold 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 42
#      30 model = XGBClassifier(
#      31     **study.best_params,
#      32     device=device,
#    (...)     37     verbosity=0
#      38 )
#      40 print(f'Training fold {fold}')
# ---> 42 model.fit(
#      43     X_train,
#      44     y_train,
#      45     sample_weight=sample_weights,
#      46     eval_set=[(X_val, y_val)],
#      47     verbose=False
#      48 )
#      50 fold_histories.append(model.evals_result())
#      52 oof_probs[val_idx] += model.predict_proba(X_val) / len(SEEDS)
#
# File ~/miniconda3/envs/ds/lib/python3.12/site-packages/xgboost/core.py:751, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     749 for k, arg in zip(sig.parameters, args):
#     750     kwargs[k] = arg
# --> 751 return func(**kwargs)
#
# File ~/miniconda3/envs/ds/lib/python3.12/site-packages/xgboost/sklearn.py:1806, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1786 evals_result: EvalsLog = {}
#    1787 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1788     missing=self.missing,
#    1789     X=X,
#    (...)   1803     feature_types=feature_types,
#    1804 )
# -> 1806 self._Booster = train(
#    1807     params,
#    1808     train_dmatrix,
#    1809     self.get_num_boosting_rounds(),
#    1810     evals=evals,
#    1811     early_stopping_rounds=self.early_stopping_rounds,
#    1812     evals_result=evals_result,
#    1813     obj=obj,
#    1814     custom_metric=metric,
#    1815     verbose_eval=verbose,
#    1816     xgb_model=model,
#    1817     callbacks=self.callbacks,
#    1818 )
#    1820 if not callable(self.objective):
#    1821     self.objective = params["objective"]
#
# File ~/miniconda3/envs/ds/lib/python3.12/site-packages/xgboost/core.py:751, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     749 for k, arg in zip(sig.parameters, args):
#     750     kwargs[k] = arg
# --> 751 return func(**kwargs)
#
# File ~/miniconda3/envs/ds/lib/python3.12/site-packages/xgboost/training.py:200, in train(params, dtrain, num_boost_round, evals, obj, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     198 if cb_container.before_iteration(bst, i, dtrain, evals):
#     199     break
# --> 200 bst.update(dtrain, iteration=i, fobj=obj)
#     201 if cb_container.after_iteration(bst, i, dtrain, evals):
#     202     break
#
# File ~/miniconda3/envs/ds/lib/python3.12/site-packages/xgboost/core.py:2391, in Booster.update(self, dtrain, iteration, fobj)
#    2387 self._assign_dmatrix_features(dtrain)
#    2389 if fobj is None:
#    2390     _check_call(
# -> 2391         _LIB.XGBoosterUpdateOneIter(
#    2392             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2393         )
#    2394     )
#    2395     return
#    2397 # Forward the gradient calculation to the boost method.
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(6, 3))

for i, history in enumerate(fold_histories, 1):
    plt.plot(history["validation_0"]["mlogloss"], label=f"Fold {i}")

plt.xlabel("Boosting Round")
plt.ylabel("MLogLoss")
plt.title("Validation MLogLoss by Fold")
plt.legend()
plt.show()

# %%
print("OOF Accuracy:", accuracy_score(y, oof_preds))
print("OOF Balanced Accuracy:", balanced_accuracy_score(y, oof_preds))
print(classification_report(y, oof_preds, target_names=le.classes_))
# Out:
# OOF Accuracy: 0.9632612622911352
# OOF Balanced Accuracy: 0.9661421587226219
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.96      0.97    377480
#          QSO       0.95      0.97      0.96    117143
#         STAR       0.88      0.96      0.92     82724
#
#     accuracy                           0.96    577347
#    macro avg       0.94      0.97      0.95    577347
# weighted avg       0.97      0.96      0.96    577347

# %%
def optimize_class_weights(oof_probs, y_true):
    def objective(weights):
        weighted_probs = oof_probs * weights
        preds = np.argmax(weighted_probs, axis=1)
        return -balanced_accuracy_score(y_true, preds)

    bounds = [(0.5, 2.0), (0.5, 2.0), (0.5, 2.0)]

    result = differential_evolution(
        objective,
        bounds=bounds,
        seed=42,
        polish=True
    )

    return result.x, -result.fun

best_weights, best_score = optimize_class_weights(oof_probs, y)

uncalibrated_preds = np.argmax(oof_probs, axis=1)
calibrated_preds = np.argmax(oof_probs * best_weights, axis=1)

print("Uncalibrated balanced accuracy:", balanced_accuracy_score(y, uncalibrated_preds))
print("Calibrated balanced accuracy:", balanced_accuracy_score(y, calibrated_preds))
print(classification_report(y, calibrated_preds, target_names=le.classes_))
# Out:
# Uncalibrated balanced accuracy: 0.9661421587226219
# Calibrated balanced accuracy: 0.9663943175580295
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.96      0.97    377480
#          QSO       0.95      0.98      0.96    117143
#         STAR       0.87      0.97      0.91     82724
#
#     accuracy                           0.96    577347
#    macro avg       0.94      0.97      0.95    577347
# weighted avg       0.96      0.96      0.96    577347

# %%
test_preds = np.argmax(test_probs * best_weights, axis=1)
test_pred_labels = le.inverse_transform(test_preds)

submission = pd.DataFrame({
    "id": test.index,
    "class": test_pred_labels
})

submission.to_csv(DATA_DIR / "submission_xgboost_v4.csv", index=False)

submission.head()
# Out:
#        id   class
# 0  577347  GALAXY
# 1  577348  GALAXY
# 2  577349  GALAXY
# 3  577350    STAR
# 4  577351  GALAXY
